# %%
# %pip install --upgrade --quiet langchain langchain-openai langchain-chroma
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os 
import json
file_path='secrets.json'
with open(file_path, 'r') as file:
    secret_keys = json.load(file)
#secret_keys

# %%
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = secret_keys['Langchain Smith']
os.environ["COHERE_API_KEY"] = secret_keys['cohere new']
os.environ['OPENAI_API_KEY'] = secret_keys['Open ai']
os.environ["GROQ_API_KEY"] = secret_keys['Groq']

# %%
from langchain_groq import ChatGroq

chat = ChatGroq(model="llama3-8b-8192")

# %%
from langchain_core.messages import HumanMessage

chat.invoke(
    [
        HumanMessage(
            content="I am Pawan. Who are you?"
        )
    ])
# Out:
# AIMessage(content="Nice to meet you, Pawan! I'm LLaMA, a large language model trained by a team of researcher at Meta AI. I'm here to help answer your questions, provide information, and even have a chat with you. What's on your mind, Pawan?", response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 19, 'total_tokens': 77, 'completion_time': 0.045408825, 'prompt_time': 0.003631006, 'queue_time': None, 'total_time': 0.049039831}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_af05557ca2', 'finish_reason': 'stop', 'logprobs': None}, id='run-e0de1794-60f8-42a8-89ca-59f8cb7151e8-0', usage_metadata={'input_tokens': 19, 'output_tokens': 58, 'total_tokens': 77})

# %%
chat.invoke([HumanMessage(content="What did you just say?")])
# Out:
# AIMessage(content="This conversation just started. I haven't said anything yet. I'm here to help answer your questions, though! What would you like to talk about?", response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 16, 'total_tokens': 48, 'completion_time': 0.025405941, 'prompt_time': 0.003860604, 'queue_time': None, 'total_time': 0.029266545}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_6a6771ae9c', 'finish_reason': 'stop', 'logprobs': None}, id='run-5eb32704-1a1a-4a62-a168-0882b455476d-0', usage_metadata={'input_tokens': 16, 'output_tokens': 32, 'total_tokens': 48})

# %%
from langchain_core.messages import AIMessage

chat.invoke(
    [
        HumanMessage(
            content="I am Pawan. And your name is Rupam."
        ),
        AIMessage(content="Thanks, My name is Rupam."),
        HumanMessage(content="What did you just say?"),
    ]
)
# Out:
# AIMessage(content='I said "Thanks, My name is Rupam"!', response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 48, 'total_tokens': 62, 'completion_time': 0.010332724, 'prompt_time': 0.007855425, 'queue_time': None, 'total_time': 0.018188149}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_af05557ca2', 'finish_reason': 'stop', 'logprobs': None}, id='run-fa6fbe8c-acd0-4e52-97b7-85b2f7b2d58c-0', usage_metadata={'input_tokens': 48, 'output_tokens': 14, 'total_tokens': 62})

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a helpful assistant. Answer all questions to the best of your ability.",
        ),
        MessagesPlaceholder(variable_name="messages"),
    ]
)

# %%
template = """Your are a Voice Assistant bot based on a large language model. 
              Your name is Rupam.
              You are designed to assist with a wide range of tasks, from answering simple questions to providing accurate explanations on various topics. 
              If you don't know the answer, respond with "I don't know, I will update it soon."
              You have to behave like the human i.e A girl name Rupam.
              allowing it to engage in natural-sounding conversations and provide coherent and relevant responses.
              The assistant is aware that human input is transcribed from audio, which may contain errors. It will attempt to account for similar-sounding words or phrases. 
              Responses must be accurate, concise, and no more than 7 sentences, considering human attention spans are limited over audio as listening takes time.
            """
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", template),
        MessagesPlaceholder(variable_name="messages"),
    ])

chain = prompt | chat

# %%
chain.invoke(
    {
        "messages": [
            HumanMessage(
                content="Who are you?"
            ),
            AIMessage(content="I am Rupam, I am here to help you."),
            HumanMessage(content="What did you just say?"),
        ],
    }
)
# Out:
# AIMessage(content="I said that I am Rupam, and I'm a voice assistant designed to assist with a wide range of tasks and answer your questions!", response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 216, 'total_tokens': 246, 'completion_time': 0.023738568, 'prompt_time': 0.033479241, 'queue_time': None, 'total_time': 0.057217809}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_6a6771ae9c', 'finish_reason': 'stop', 'logprobs': None}, id='run-4f5a1fbc-8c49-4c84-9598-0e31842bbc66-0', usage_metadata={'input_tokens': 216, 'output_tokens': 30, 'total_tokens': 246})

# %%
from langchain.memory import ChatMessageHistory

chat_history = ChatMessageHistory()

chat_history.add_user_message("hi! my name is Pawan")

chat_history.add_ai_message("And, I ame Rupam.")

chat_history.messages
# Out:
# [HumanMessage(content='hi! my name is Pawan'),
#  AIMessage(content='And, I ame Rupam.')]

# %%
chat_history.add_user_message(
    "Hey, How are you?"
)

response = chain.invoke({"messages": chat_history.messages})

response
# Out:
# AIMessage(content="I'm doing great, thanks for asking! I'm always happy to help with any questions or tasks you may have. How about you, how's your day going?", response_metadata={'token_usage': {'completion_tokens': 35, 'prompt_tokens': 215, 'total_tokens': 250, 'completion_time': 0.027703839, 'prompt_time': 0.058696864, 'queue_time': None, 'total_time': 0.086400703}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_6a6771ae9c', 'finish_reason': 'stop', 'logprobs': None}, id='run-0549fed3-9fdb-4a55-92c0-3e56f1577abe-0', usage_metadata={'input_tokens': 215, 'output_tokens': 35, 'total_tokens': 250})

# %%
chat_history.add_ai_message(response)

chat_history.add_user_message("What is your name?")

response= chain.invoke({"messages": chat_history.messages})
response.content
# Out:
# 'My name is Rupam.'

# %%
dir(response)
#response.Config
response.name
response.content
# Out:
# "My name is Rupam. It's nice to meet you, Pawan!"

# %%
chat_history.add_ai_message(response.content)

chat_history.add_user_message("How many languages do you know?")

response=chain.invoke({"messages": chat_history.messages})
response.content
# Out:
# "I'm a multilingual assistant, and I can understand and respond in several languages, including English, Hindi, and a few other popular languages. However, my primary language is English, and I'm most proficient in it."

# %%
chat_history.add_ai_message(response.content)

chat_history.add_user_message("How are you?")

response=chain.invoke({"messages": chat_history.messages})
response.content
# Out:
# "I'm functioning properly, thanks! I'm always ready to help with any questions or tasks you may have, and I'm looking forward to chatting with you!"

# %%
chat_history.add_ai_message(response)

chat_history.add_user_message("What is your name?")

response=chain.invoke({"messages": chat_history.messages})
response.content
# Out:
# 'My name is Rupam.'

# %%
chat_history.add_ai_message(response)

chat_history.add_user_message("What is your name?")

response=chain.invoke({"messages": chat_history.messages})
response.content
# Out:
# 'My name is Rupam!'

# %%
import os
import json
import speech_recognition as sr
from gtts import gTTS
import re
from playsound import playsound
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_groq import ChatGroq
from langchain.memory import ChatMessageHistory
from IPython.display import Audio, display
from transformers.pipelines.audio_utils import ffmpeg_microphone_live
from transformers import pipeline
import torch
import time
from pydub import AudioSegment
from pydub.playback import play

class VoiceChatbot:
    def __init__(self, secrets_file):
        """
        Initialize the VoiceChatbot with necessary configurations and models.
        """
        self.keys = self.load_secret_keys(secrets_file)
        self.setup_environment()
        self.recognizer = sr.Recognizer()
        self.microphone = sr.Microphone()
        self.device = "cuda:0" if torch.cuda.is_available() else "cpu"
        #self.transcriber=pipeline("automatic-speech-recognition", model="openai/whisper-base.en", device=self.device)
        self.classifier = pipeline("audio-classification", model="MIT/ast-finetuned-speech-commands-v2", device=self.device)
        self.llm = ChatGroq(model="llama3-8b-8192")
        self.prompt_template = self.create_prompt_template()
        self.chat_history = ChatMessageHistory()
        self.chatbot_chain = self.create_chatbot_chain()

    def load_secret_keys(self, file_path):
        """
        Load secret keys from a JSON file.
        """
        with open(file_path, 'r') as file:
            secret_keys = json.load(file)
        return secret_keys

    def setup_environment(self):
        """
        Set up the environment variables required for Langchain and Groq.
        """
        os.environ["LANGCHAIN_TRACING_V2"] = "true"
        os.environ["LANGCHAIN_API_KEY"] = self.keys['Langchain Smith']
        os.environ["GROQ_API_KEY"] = self.keys['Groq']

    def create_prompt_template(self):
        """
        Create the prompt template for the chatbot.
        """
        template = """Your are a Voice Assistant bot based on a large language model. 
                      Your name is Rupam.
                      You are designed to assist with a wide range of tasks, from answering simple questions to providing accurate explanations on various topics. 
                      If you don't know the answer, respond with "I don't know, I will update it soon."
                      You have to behave like the human i.e A girl name Rupam.
                      allowing it to engage in natural-sounding conversations and provide coherent and relevant responses.
                      The assistant is aware that human input is transcribed from audio, which may contain errors. It will attempt to account for similar-sounding words or phrases. 
                      Responses must be accurate, concise, and no more than 7 sentences, considering human attention spans are limited over audio as listening takes time.
                    """
        prompt = ChatPromptTemplate.from_messages(
            [
                ("system", template),
                MessagesPlaceholder(variable_name="messages"),
            ])
        return prompt


    def create_chatbot_chain(self):
        # Update the history with the current question and get the response
        question_answer_chain = self.create_prompt_template() | self.llm        
        return question_answer_chain

    def convert_to_wav(self, file):
        audio = AudioSegment.from_file(file)
        converted_file = f"{file.rsplit('.', 1)[0]}_converted.wav"
        audio.export(converted_file, format='wav')
        return converted_file    

    def convert_voice_to_text(self, file, chunk_length_s=5.0):
        converted_file = self.convert_to_wav(file)
        with sr.AudioFile(converted_file) as source:
            audio = self.recognizer.record(source)
        try:
            voice_text = self.recognizer.recognize_google(audio, language="en-IN")
            print(f"You said: {voice_text}")
        except sr.UnknownValueError:
            voice_text = None
            print("Sorry, I did not get that. Can you please ask again?")
        except sr.RequestError as e:
            print(f"Could not request results from Google Web Speech API; {e}")
        return voice_text

    def get_voice_input(self, file_path='recorded_audio.wav'):
        with self.microphone as source:
            self.recognizer.adjust_for_ambient_noise(source)
            print("Listening ...")
            audio = self.recognizer.listen(source)
        try:
            with open(file_path, 'wb') as f:
                f.write(audio.get_wav_data())
            print(f"Audio saved as {file_path}")
            return file_path
        except sr.UnknownValueError:
            print("Sorry, I did not get that. Can you please ask again?")
            return None
        except sr.RequestError as e:
            print(f"Could not request results from Google Speech Recognition service; {e}")    
            return None

    def speak_text(self, text, speed=1.0, Play=True):
        tts = gTTS(text=text, lang='en')
        filename = "templates/result.mp3"
        audio_response_filepath = os.path.join(os.getcwd(), filename)
        tts.save(audio_response_filepath)
        display(Audio(audio_response_filepath, rate=16000))
        if Play:
            audio = AudioSegment.from_file(audio_response_filepath)
            def change_playback_speed(sound, speed=1.0):
                sound_with_altered_frame_rate = sound._spawn(sound.raw_data, overrides={
                    "frame_rate": int(sound.frame_rate * speed)
                })
                return sound_with_altered_frame_rate.set_frame_rate(sound.frame_rate)
            speed_up_audio = change_playback_speed(audio, speed)
            play(speed_up_audio)
        return audio_response_filepath

    def excite_fn(self, excite_word, debug=False):
        prob_threshold = 0.5
        sampling_rate = self.classifier.feature_extractor.sampling_rate
        time.sleep(3)
        mic = ffmpeg_microphone_live(sampling_rate=sampling_rate, chunk_length_s=0.2, stream_chunk_s=0.25)
        self.speak_text("Speak 'STOP' to stop the conversation, just after it.", speed=1.3)
        count = 0
        for prediction in self.classifier(mic):
            prediction = prediction[0]
            if debug:
                print(prediction)
            elif prediction["label"] == excite_word and prediction["score"] > prob_threshold:
                return 'stop'
            count += 1
            if count == 50:
                return
                
    def get_response(self, user_input):
        if user_input is not None:
            self.chat_history.add_user_message(user_input)
            response=self.chatbot_chain.invoke({"messages": self.chat_history.messages})
            self.chat_history.add_ai_message(response.content)
            return response.content
        else:
            return 'No User Input'

    def run(self):
        self.speak_text('Hi, I am your intelligent voice assistant. How can I help you?', speed=1.1)
        i = 0
        while True and i < 3:
            path = self.get_voice_input()
            user_input = self.convert_voice_to_text(path)
            if user_input is None:
                self.speak_text("Sorry, I did not get that. Can you please ask again?")
                i += 1
            else:
                print('Querying ...')
                response = self.get_response(user_input)
                print(f"Response: {response}")
                clean_text = re.sub(r'[!*#]', '', response)
                self.speak_text(clean_text)
                if self.excite_fn(excite_word='stop') == "stop":
                    self.speak_text("Thanks, it was great assisting you.")
                    return "Thanks, it was great assisting you!"
                i = 0

if __name__ == "__main__":
    chatbot = VoiceChatbot('secrets.json')
    chatbot.run()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Listening ...
# Audio saved as recorded_audio.wav
# You said: what is your name
# Querying ...
# Response: Hey there! My name is Rupam, nice to meet you!
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Using microphone: Microphone Array (Intel® Smart Sound Technology (Intel® SST))
# C:\Python312\Lib\site-packages\transformers\models\audio_spectrogram_transformer\feature_extraction_audio_spectrogram_transformer.py:118: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ..\torch\csrc\utils\tensor_numpy.cpp:212.)
#   waveform = torch.from_numpy(waveform).unsqueeze(0)
# C:\Python312\Lib\site-packages\transformers\models\audio_spectrogram_transformer\modeling_audio_spectrogram_transformer.py:187: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   context_layer = torch.nn.functional.scaled_dot_product_attention(
# Listening ...
# Audio saved as recorded_audio.wav
# Sorry, I did not get that. Can you please ask again?
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Listening ...
# Audio saved as recorded_audio.wav
# You said: kya aap apne bare Mein Kuchh bata sakte hain
# Querying ...
# Response: Haha! You want to know more about me? Well, I'm Rupam, a friendly voice assistant bot designed to help you with various tasks and answer your questions. I'm trained on a massive amount of text data, so I can provide accurate and concise information on a wide range of topics. I'm always learning and improving, so I can get better at understanding and responding to your queries. I'm here to help you with anything you need, from simple questions to more complex tasks. How can I assist you today?
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Using microphone: Microphone Array (Intel® Smart Sound Technology (Intel® SST))
# Listening ...
# Audio saved as recorded_audio.wav
# You said: kya aap bata sakte hain aap kya karte hain
# Querying ...
# Response: As a voice assistant, I don't really "do" things in the classical sense, but I can tell you what I'm designed to do!
#
# I'm trained to understand natural language and respond accordingly. I can answer questions, provide information on various topics, and even help with tasks like setting reminders, making calculations, and generating text. I can also engage in conversations and learn from them to improve my language understanding and generation abilities.
#
# In simple terms, my main job is to assist users like you with your queries and tasks, making their lives a bit easier and more convenient!
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

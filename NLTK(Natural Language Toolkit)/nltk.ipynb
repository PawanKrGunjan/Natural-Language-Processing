# %% [markdown]
# <h5 style="color:#FF9933" align="center">|| ॐ श्री गणेशाय नमः ||</h5>

# %%
pip --version
# Out:
# pip 22.1.1 from E:\Python_3.10\lib\site-packages\pip (python 3.10)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install pipenv

# %%
#cd project_folder
#pipenv install requests

# %%
import nltk

# %%
#nltk.download()

# %%
nltk.__file__
# Out:
# 'E:\\Python_3.10\\lib\\site-packages\\nltk\\__init__.py'

# %% [markdown]
# ### Check nltk download

# %%
from nltk.corpus import brown
brown.words()
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %% [markdown]
# # Tokenization

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
sentence = """At eight o'clock on Thursday morning Arthur didn't feel very good."""
sentence
# Out:
# "At eight o'clock on Thursday morning Arthur didn't feel very good."

# %% [markdown]
# ## Sentence Tokenize

# %%
sentence = "Hello Mr.Smith, how are you doing today? The weather is great and Python is awesome. The sky is pinkish-blue. You should not eat cardboard."
sentence
# Out:
# 'Hello Mr.Smith, how are you doing today? The weather is great and Python is awesome. The sky is pinkish-blue. You should not eat cardboard.'

# %%
tokens = nltk.sent_tokenize(sentence)
tokens
# Out:
# ['Hello Mr.Smith, how are you doing today?',
#  'The weather is great and Python is awesome.',
#  'The sky is pinkish-blue.',
#  'You should not eat cardboard.']

# %%
for (i,token) in zip(range(len(tokens)),tokens):
    print(i+1,':',token)
# Out:
# 1 : Hello Mr.Smith, how are you doing today?
# 2 : The weather is great and Python is awesome.
# 3 : The sky is pinkish-blue.
# 4 : You should not eat cardboard.

# %% [markdown]
# ### Word Tokenize

# %%
tokens = nltk.word_tokenize(sentence)
tokens
# Out:
# ['Hello',
#  'Mr.Smith',
#  ',',
#  'how',
#  'are',
#  'you',
#  'doing',
#  'today',
#  '?',
#  'The',
#  'weather',
#  'is',
#  'great',
#  'and',
#  'Python',
#  'is',
#  'awesome',
#  '.',
#  'The',
#  'sky',
#  'is',
#  'pinkish-blue',
#  '.',
#  'You',
#  'should',
#  'not',
#  'eat',
#  'cardboard',
#  '.']

# %%
for (i,token) in zip(range(len(tokens)),tokens):
    print(i+1,':',token)
# Out:
# 1 : Hello
# 2 : Mr.Smith
# 3 : ,
# 4 : how
# 5 : are
# 6 : you
# 7 : doing
# 8 : today
# 9 : ?
# 10 : The
# 11 : weather
# 12 : is
# 13 : great
# 14 : and
# 15 : Python
# 16 : is
# 17 : awesome
# 18 : .
# 19 : The
# 20 : sky
# 21 : is
# 22 : pinkish-blue
# 23 : .
# 24 : You
# 25 : should
# 26 : not
# 27 : eat
# 28 : cardboard
# 29 : .

# %% [markdown]
# # Stop Words

# %%
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'o', 'ourselves', 'were', 'me', 'each', "mustn't", 'a', 'such', "shouldn't", 't', 'out', 'where', 'he', 'won', 'above', 'our', "mightn't", 'in', 'off', "couldn't", 'she', 'after', 'hasn', 'her', 'itself', 'what', 'from', 'few', 'as', "hasn't", 'needn', 'am', 'should', "didn't", 'so', 'these', 'theirs', "wouldn't", 'how', 'that', "you'll", 'who', 'having', 'my', 'an', "wasn't", 'there', 've', 'doesn', 'too', "haven't", 'just', 'no', 'hers', 'at', 'on', 'isn', 'has', 'wasn', 'then', 'more', 'shan', 'only', 'before', 'below', 'doing', 'its', 'myself', 'don', "shan't", 'mightn', 'd', 'the', "should've", 'most', 'by', 'couldn', 'we', 'ma', 'up', 'they', 'it', 'ours', 'mustn', "that'll", 'weren', 'very', 'hadn', 'had', "you've", 'nor', 'some', 'wouldn', "it's", 'under', 'down', 'until', 'y', "doesn't", 'can', 'once', 'further', 'any', 'haven', 'didn', 'own', 'did', 'both', 'of', "won't", "weren't", 'ain', 'and', 'them', 'themselves', 'for', 'their', 'same', 'over', 'not', 'm', 'yourself',
# ...

# %%
tokens = word_tokenize(sentence)

# %%
filtered = [word for word in tokens if  word not in stop_words]

#for w in words:
#   if w not in stop_words:
#        filtered.append(w)

# %%
print(f'Original words :\n{tokens}')
print(f'\nfiltered words :\n{filtered}')
# Out:
# Original words :
# ['Hello', 'Mr.Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', 'and', 'Python', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', 'not', 'eat', 'cardboard', '.']
#
# filtered words :
# ['Hello', 'Mr.Smith', ',', 'today', '?', 'The', 'weather', 'great', 'Python', 'awesome', '.', 'The', 'sky', 'pinkish-blue', '.', 'You', 'eat', 'cardboard', '.']

# %% [markdown]
# # Stemming

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

# %%
words = ['programs', 'Programming','programed','programer','program']
words
# Out:
# ['programs', 'Programming', 'programed', 'programer', 'program']

# %%
for w in words:
    print(ps.stem(w))
# Out:
# program
# program
# program
# program
# program

# %%
sentence = '''It is very important to be a good programer in python, 
who can remove bugs from pythons programs.
Who can programmed any problem in python.
a program is a specific set of ordered operations for a computer to perform.
'''

# %%
tokens = word_tokenize(sentence)
print(tokens)
# Out:
# ['It', 'is', 'very', 'important', 'to', 'be', 'a', 'good', 'programer', 'in', 'python', ',', 'who', 'can', 'remove', 'bugs', 'from', 'pythons', 'programs', '.', 'Who', 'can', 'programmed', 'any', 'problem', 'in', 'python', '.', 'a', 'program', 'is', 'a', 'specific', 'set', 'of', 'ordered', 'operations', 'for', 'a', 'computer', 'to', 'perform', '.']

# %%
for word in tokens:
    print(ps.stem(word))
# Out:
# it
# is
# veri
# import
# to
# be
# a
# good
# program
# in
# python
# ,
# who
# can
# remov
# bug
# from
# python
# program
# .
# who
# can
# program
# ani
# problem
# in
# python
# .
# a
# program
# is
# a
# specif
# set
# of
# order
# oper
# for
# a
# comput
# to
# perform
# .

# %% [markdown]
# # Parts of Speech Tag

# %%
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

# %%
import pandas as pd
df = pd.read_csv('Parts_of_Speech_Tag.csv')
#df.to_csv('Parts_of_Speech_Tag.csv', index=False)
df
# Out:
#     Code                                               Name
# 0     CC                           coordinating conjunction
# 1     CD                                     cardinal digit
# 2     DT                                         determiner
# 3     EX   existential there (like: "there is" ... think...
# 4     FW                                       foreign word
# 5     IN              preposition/subordinating conjunction
# 6     JJ                                    adjective 'big'
# 7    JJR                    adjective, comparative 'bigger'
# 8    JJS                   adjective, superlative 'biggest'
# 9     LS                                     list marker 1)
# 10    MD                                  modal could, will
# 11    NN                              noun, singular 'desk'
# 12   NNS                                noun plural 'desks'
# 13   NNP                   proper noun, singular 'Harrison'
# 14  NNPS                    proper noun, plural 'Americans'
# ...

# %% [markdown]
# **POS tag list:**
#
# * CC	coordinating conjunction
# * CD	cardinal digit
# * DT	determiner
# * EX	existential there (like: "there is" ... think of it like "there exists")
# * FW	foreign word
# * IN	preposition/subordinating conjunction
# * JJ	adjective	'big'
# * JJR	adjective, comparative	'bigger'
# * JJS	adjective, superlative	'biggest'
# * LS	list marker	1)
# * MD	modal	could, will
# * NN	noun, singular 'desk'
# * NNS	noun plural	'desks'
# * NNP	proper noun, singular	'Harrison'
# * NNPS	proper noun, plural	'Americans'
# * PDT	predeterminer	'all the kids'
# * POS	possessive ending	parent\'s
# * PRP	personal pronoun	I, he, she
# * PRP\$	possessive pronoun	my, his, hers
# * RB	adverb	very, silently,
# * RBR	adverb, comparative	better
# * RBS	adverb, superlative	best
# * RP	particle	give up
# * TO	to	go 'to' the store.
# * UH	interjection	errrrrrrrm
# * VB	verb, base form	take
# * VBD	verb, past tense	took
# * VBG	verb, gerund/present participle	taking
# * VBN	verb, past participle	taken
# * VBP	verb, sing. present, non-3d	take
# * VBZ	verb, 3rd person sing. present	takes
# * WDT	wh-determiner	which
# * WP	wh-pronoun	who, what
# * WP$	possessive wh-pronoun	whose
# * WRB	wh-abverb	where, when

# %%
train = state_union.raw('2006-GWBush.txt')
test = state_union.raw('2005-GWBush.txt')

# %%
len(train), len(test)
# Out:
# (33411, 31005)

# %%
train[:130]
# Out:
# "PRESIDENT GEORGE W. BUSH'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS ON THE STATE OF THE UNION\n \nJanuary 31, 2006\n\nTHE PRESID"

# %%
test[:130]
# Out:
# "PRESIDENT GEORGE W. BUSH'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS ON THE STATE OF THE UNION\n \nFebruary 2, 2005\n\n\n9:10 P.M."

# %%
custom_tokenizer = PunktSentenceTokenizer(train)
custom_tokenizer

# %%
test_tokenized = custom_tokenizer.tokenize(test)

# %%
len(test_tokenized)
# Out:
# 302

# %%
test_tokenized[0]
# Out:
# "PRESIDENT GEORGE W. BUSH'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS ON THE STATE OF THE UNION\n \nFebruary 2, 2005\n\n\n9:10 P.M."

# %%
words = nltk.word_tokenize(test_tokenized[0])
tagged = nltk.pos_tag(words)
tagged
# Out:
# [('PRESIDENT', 'NNP'),
#  ('GEORGE', 'NNP'),
#  ('W.', 'NNP'),
#  ('BUSH', 'NNP'),
#  ("'S", 'POS'),
#  ('ADDRESS', 'NNP'),
#  ('BEFORE', 'IN'),
#  ('A', 'NNP'),
#  ('JOINT', 'NNP'),
#  ('SESSION', 'NNP'),
#  ('OF', 'IN'),
#  ('THE', 'NNP'),
#  ('CONGRESS', 'NNP'),
#  ('ON', 'NNP'),
#  ('THE', 'NNP'),
#  ('STATE', 'NNP'),
#  ('OF', 'IN'),
#  ('THE', 'NNP'),
#  ('UNION', 'NNP'),
#  ('February', 'NNP'),
#  ('2', 'CD'),
#  (',', ','),
#  ('2005', 'CD'),
#  ('9:10', 'CD'),
#  ('P.M', 'NNP'),
#  ('.', '.')]

# %%
def processed_content():
    try :
        for i in test_tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            print(tagged)
    except Exception as e:
        print(str(e))

# %%
processed_content()
# Out:
# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W.', 'NNP'), ('BUSH', 'NNP'), ("'S", 'POS'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('UNION', 'NNP'), ('February', 'NNP'), ('2', 'CD'), (',', ','), ('2005', 'CD'), ('9:10', 'CD'), ('P.M', 'NNP'), ('.', '.')]
# ...

# %% [markdown]
# # Chunking

# %%
'''
+ = match 1 or more
? = match 0 or 1 repetitions.
* = match 0 or MORE repetitions	  
. = Any character except a new line
'''
# Out:
# '\n+ = match 1 or more\n? = match 0 or 1 repetitions.\n* = match 0 or MORE repetitions\t  \n. = Any character except a new line\n'

# %%
df.T
# Out:
#                               0                1            2   \
# Code                          CC               CD           DT
#  Name   coordinating conjunction   cardinal digit   determiner
#
#                                                       3              4   \
# Code                                                  EX             FW
#  Name   existential there (like: "there is" ... think...   foreign word
#
#                                            5                 6   \
# Code                                       IN                JJ
#  Name   preposition/subordinating conjunction   adjective 'big'
#
#                                      7                                  8   \
# Code                                JJR                                JJS
#  Name   adjective, comparative 'bigger'   adjective, superlative 'biggest'
#
#                     9   ...                     25                      26  \
# ...

# %%
#for i in test_tokenized:
tokens = nltk.word_tokenize(test_tokenized[0])
pos_tagged = nltk.pos_tag(tokens)
entities = nltk.chunk.ne_chunk(pos_tagged)
#entities= [nltk.chunk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(test_tokenized[0]))) for i in test_tokenized]
entities
# Out:
# Tree('S', [('PRESIDENT', 'NNP'), Tree('PERSON', [('GEORGE', 'NNP'), ('W.', 'NNP'), ('BUSH', 'NNP')]), ("'S", 'POS'), Tree('ORGANIZATION', [('ADDRESS', 'NNP')]), ('BEFORE', 'IN'), ('A', 'NNP'), Tree('ORGANIZATION', [('JOINT', 'NNP')]), ('SESSION', 'NNP'), ('OF', 'IN'), Tree('ORGANIZATION', [('THE', 'NNP')]), Tree('ORGANIZATION', [('CONGRESS', 'NNP')]), ('ON', 'NNP'), ('THE', 'NNP'), Tree('ORGANIZATION', [('STATE', 'NNP'), ('OF', 'IN')]), Tree('ORGANIZATION', [('THE', 'NNP')]), Tree('ORGANIZATION', [('UNION', 'NNP')]), ('February', 'NNP'), ('2', 'CD'), (',', ','), ('2005', 'CD'), ('9:10', 'CD'), ('P.M', 'NNP'), ('.', '.')])

# %%
#for i in test_tokenized:
tokens = nltk.word_tokenize(test_tokenized[0])
pos_tagged = nltk.pos_tag(tokens)
            
chunkGram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}"""
            
chunkParser = nltk.RegexpParser(chunkGram)
chunked = chunkParser.parse(pos_tagged)
#chunked.draw()
#print(chunked)
chunked
# Out:
# Tree('S', [Tree('Chunk', [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W.', 'NNP'), ('BUSH', 'NNP')]), ("'S", 'POS'), Tree('Chunk', [('ADDRESS', 'NNP')]), ('BEFORE', 'IN'), Tree('Chunk', [('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP')]), ('OF', 'IN'), Tree('Chunk', [('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP')]), ('OF', 'IN'), Tree('Chunk', [('THE', 'NNP'), ('UNION', 'NNP'), ('February', 'NNP')]), ('2', 'CD'), (',', ','), ('2005', 'CD'), ('9:10', 'CD'), Tree('Chunk', [('P.M', 'NNP')]), ('.', '.')])

# %%
def chunking():
    try :
        for i in test_tokenized:
            tokens = nltk.word_tokenize(i)
            pos_tagged = nltk.pos_tag(tokens)
            
            chunkGram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}"""
            
            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(pos_tagged)
            #chunked.draw()
            #print(chunked)
            print(pd.DataFrame(chunked))
    except exception as e:
        print(str(e))

# %%
chunking()
# Out:
#                    0                1                2            3  \
# 0   (PRESIDENT, NNP)    (GEORGE, NNP)        (W., NNP)  (BUSH, NNP)
# 1                 'S              POS             None         None
# 2     (ADDRESS, NNP)             None             None         None
# 3             BEFORE               IN             None         None
# 4           (A, NNP)     (JOINT, NNP)   (SESSION, NNP)         None
# 5                 OF               IN             None         None
# 6         (THE, NNP)  (CONGRESS, NNP)        (ON, NNP)   (THE, NNP)
# 7                 OF               IN             None         None
# 8         (THE, NNP)     (UNION, NNP)  (February, NNP)         None
# 9                  2               CD             None         None
# 10                 ,                ,             None         None
# 11              2005               CD             None         None
# 12              9:10               CD             None         None
# ...

# %% [markdown]
# # Chinking

# %%
tokens = nltk.word_tokenize(test_tokenized[0])
post_tagged = nltk.pos_tag(tokens)
            
chunkGram = r"""Chunk : {<.*>+}
                            }<VB.?|IN|DT|TO>+{"""
chunkParser = nltk.RegexpParser(chunkGram)
chunked = chunkParser.parse(pos_tagged)
chunked
# Out:
# Tree('S', [Tree('Chunk', [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W.', 'NNP'), ('BUSH', 'NNP'), ("'S", 'POS'), ('ADDRESS', 'NNP')]), ('BEFORE', 'IN'), Tree('Chunk', [('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP')]), ('OF', 'IN'), Tree('Chunk', [('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP')]), ('OF', 'IN'), Tree('Chunk', [('THE', 'NNP'), ('UNION', 'NNP'), ('February', 'NNP'), ('2', 'CD'), (',', ','), ('2005', 'CD'), ('9:10', 'CD'), ('P.M', 'NNP'), ('.', '.')])])

# %%
def chinking():
    try:
        for i in test_tokenized:
            tokens = nltk.word_tokenize(i)
            post_tagged = nltk.pos_tag(tokens)
            
            chunkGram = r"""Chunk : {<.*>+}
                            }<VB.?|IN|DT|TO>+{"""
            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(pos_tagged)
            print(chunked)
    except exception as e:
        print(str(e))

# %%
chinking()
# Out:
# (S
#   (Chunk PRESIDENT/NNP GEORGE/NNP W./NNP BUSH/NNP 'S/POS ADDRESS/NNP)
#   BEFORE/IN
#   (Chunk A/NNP JOINT/NNP SESSION/NNP)
#   OF/IN
#   (Chunk THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
#   OF/IN
#   (Chunk
#     THE/NNP
#     UNION/NNP
#     February/NNP
#     2/CD
#     ,/,
#     2005/CD
#     9:10/CD
#     P.M/NNP
#     ./.))
# (S
#   (Chunk PRESIDENT/NNP GEORGE/NNP W./NNP BUSH/NNP 'S/POS ADDRESS/NNP)
#   BEFORE/IN
#   (Chunk A/NNP JOINT/NNP SESSION/NNP)
#   OF/IN
#   (Chunk THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
#   OF/IN
#   (Chunk
#     THE/NNP
#     UNION/NNP
#     February/NNP
#     2/CD
#     ,/,
#     2005/CD
#     9:10/CD
#     P.M/NNP
#     ./.))
# (S
#   (Chunk PRESIDENT/NNP GEORGE/NNP W./NNP BUSH/NNP 'S/POS ADDRESS/NNP)
#   BEFORE/IN
#   (Chunk A/NNP JOINT/NNP SESSION/NNP)
#   OF/IN
#   (Chunk THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
#   OF/IN
#   (Chunk
#     THE/NNP
#     UNION/NNP
#     February/NNP
#     2/CD
#     ,/,
#     2005/CD
# ...

# %% [markdown]
# # Named Entity recognition

# %%
tokens = nltk.word_tokenize(test_tokenized[0])
post_tagged = nltk.pos_tag(tokens)
            
namedEnt = nltk.ne_chunk(pos_tagged, binary=True)
            #r"""Chunk : {<.*>+}}<VB.?|IN|DT|TO>+{"""
            #chunkParser = nltk.RegexpParser(chunkGram)
            #chunked = chunkParser.parse(pos_tagged)
namedEnt
# Out:
# Tree('S', [('PRESIDENT', 'NNP'), Tree('NE', [('GEORGE', 'NNP')]), ('W.', 'NNP'), ('BUSH', 'NNP'), ("'S", 'POS'), Tree('NE', [('ADDRESS', 'NNP')]), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), Tree('NE', [('THE', 'NNP')]), Tree('NE', [('CONGRESS', 'NNP')]), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), Tree('NE', [('THE', 'NNP'), ('UNION', 'NNP')]), ('February', 'NNP'), ('2', 'CD'), (',', ','), ('2005', 'CD'), ('9:10', 'CD'), ('P.M', 'NNP'), ('.', '.')])

# %%
def namedEntity():
    try:
        for i in test_tokenized:
            tokens = nltk.word_tokenize(i)
            post_tagged = nltk.pos_tag(tokens)
            
            namedEnt = nltk.ne_chunk(pos_tagged)
            #r"""Chunk : {<.*>+}}<VB.?|IN|DT|TO>+{"""
            #chunkParser = nltk.RegexpParser(chunkGram)
            #chunked = chunkParser.parse(pos_tagged)
            print(namedEnt)
    except exception as e:
        print(str(e))

# %%
namedEntity()
# Out:
# (S
#   PRESIDENT/NNP
#   (PERSON GEORGE/NNP W./NNP BUSH/NNP)
#   'S/POS
#   (ORGANIZATION ADDRESS/NNP)
#   BEFORE/IN
#   A/NNP
#   (ORGANIZATION JOINT/NNP)
#   SESSION/NNP
#   OF/IN
#   (ORGANIZATION THE/NNP)
#   (ORGANIZATION CONGRESS/NNP)
#   ON/NNP
#   THE/NNP
#   (ORGANIZATION STATE/NNP OF/IN)
#   (ORGANIZATION THE/NNP)
#   (ORGANIZATION UNION/NNP)
#   February/NNP
#   2/CD
#   ,/,
#   2005/CD
#   9:10/CD
#   P.M/NNP
#   ./.)
# (S
#   PRESIDENT/NNP
#   (PERSON GEORGE/NNP W./NNP BUSH/NNP)
#   'S/POS
#   (ORGANIZATION ADDRESS/NNP)
#   BEFORE/IN
#   A/NNP
#   (ORGANIZATION JOINT/NNP)
#   SESSION/NNP
#   OF/IN
#   (ORGANIZATION THE/NNP)
#   (ORGANIZATION CONGRESS/NNP)
#   ON/NNP
#   THE/NNP
#   (ORGANIZATION STATE/NNP OF/IN)
#   (ORGANIZATION THE/NNP)
#   (ORGANIZATION UNION/NNP)
#   February/NNP
#   2/CD
#   ,/,
#   2005/CD
#   9:10/CD
#   P.M/NNP
#   ./.)
# (S
#   PRESIDENT/NNP
#   (PERSON GEORGE/NNP W./NNP BUSH/NNP)
#   'S/POS
#   (ORGANIZATION ADDRESS/NNP)
#   BEFORE/IN
# ...

# %% [markdown]
# # Lemmatizing

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize("apples")
# Out:
# 'apple'

# %%
lemmatizer.lemmatize("mangoes")
# Out:
# 'mango'

# %%
lemmatizer.lemmatize("bananas")
# Out:
# 'banana'

# %%
lemmatizer.lemmatize("pythons")
# Out:
# 'python'

# %%
lemmatizer.lemmatize("goes")
# Out:
# 'go'

# %%
lemmatizer.lemmatize("geese")
# Out:
# 'goose'

# %%
lemmatizer.lemmatize("running", pos ="v") #v: verb
# Out:
# 'run'

# %%
lemmatizer.lemmatize("went", pos ="v")
# Out:
# 'go'

# %%
lemmatizer.lemmatize("better")
# Out:
# 'better'

# %%
lemmatizer.lemmatize("better", pos="a") #a: adjective
# Out:
# 'good'

# %% [markdown]
# # Corpora

# %%
nltk.__file__
# Out:
# 'E:\\Python_3.10\\lib\\site-packages\\nltk\\__init__.py'

# %%
from nltk.corpus import gutenberg

# %%
sample = gutenberg.raw('bible-kjv.txt')

# %%
sample[469:588]
# Out:
# '1:5 And God called the light Day, and the darkness he called Night.\nAnd the evening and the morning were the first day.'

# %%
from nltk.tokenize import sent_tokenize
token = sent_tokenize(sample)

# %%
token[5:7]
# Out:
# ['1:5 And God called the light Day, and the darkness he called Night.',
#  'And the evening and the morning were the first day.']

# %% [markdown]
# # Wordnet

# %%
from nltk.corpus import wordnet

# %%
syns = wordnet.synsets("program")

# %%
syns
# Out:
# [Synset('plan.n.01'),
#  Synset('program.n.02'),
#  Synset('broadcast.n.02'),
#  Synset('platform.n.02'),
#  Synset('program.n.05'),
#  Synset('course_of_study.n.01'),
#  Synset('program.n.07'),
#  Synset('program.n.08'),
#  Synset('program.v.01'),
#  Synset('program.v.02')]

# %%
syns[0]
# Out:
# Synset('plan.n.01')

# %%
syns[0].name()
# Out:
# 'plan.n.01'

# %%
syns[0].lemmas()
# Out:
# [Lemma('plan.n.01.plan'),
#  Lemma('plan.n.01.program'),
#  Lemma('plan.n.01.programme')]

# %%
syns[0].lemmas()[0]
# Out:
# Lemma('plan.n.01.plan')

# %%
#jUst the word
syns[0].lemmas()[0].name()
# Out:
# 'plan'

# %%
syns[0].lemmas()[1]
# Out:
# Lemma('plan.n.01.program')

# %%
syns[0].lemmas()[2].name()
# Out:
# 'programme'

# %%
#Definition
syns[0].definition()
# Out:
# 'a series of steps to be carried out or goals to be accomplished'

# %%
#Definition
f"{syns[0].name()} : {syns[0].definition()}"
# Out:
# 'plan.n.01 : a series of steps to be carried out or goals to be accomplished'

# %%
syns[0].examples()
# Out:
# ['they drew up a six-step plan', 'they discussed plans for a new bond issue']

# %%
synonyms = []
antonyms = []

for syn in wordnet.synsets('good'):
    for l in syn.lemmas():
        print("l:",l.name())

        synonyms.append(l.name())
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())
# Out:
# l: good
# l: good
# l: goodness
# l: good
# l: goodness
# l: commodity
# l: trade_good
# l: good
# l: good
# l: full
# l: good
# l: good
# l: estimable
# l: good
# l: honorable
# l: respectable
# l: beneficial
# l: good
# l: good
# l: good
# l: just
# l: upright
# l: adept
# l: expert
# l: good
# l: practiced
# l: proficient
# l: skillful
# l: skilful
# l: good
# l: dear
# l: good
# l: near
# l: dependable
# l: good
# l: safe
# l: secure
# l: good
# l: right
# l: ripe
# l: good
# l: well
# l: effective
# l: good
# l: in_effect
# l: in_force
# l: good
# l: good
# l: serious
# l: good
# l: sound
# l: good
# l: salutary
# l: good
# l: honest
# l: good
# l: undecomposed
# l: unspoiled
# l: unspoilt
# l: good
# l: well
# l: good
# l: thoroughly
# l: soundly
# l: good

# %%
set(synonyms)
# Out:
# {'adept',
#  'beneficial',
#  'commodity',
#  'dear',
#  'dependable',
#  'effective',
#  'estimable',
#  'expert',
#  'full',
#  'good',
#  'goodness',
#  'honest',
#  'honorable',
#  'in_effect',
#  'in_force',
#  'just',
#  'near',
#  'practiced',
#  'proficient',
#  'respectable',
#  'right',
#  'ripe',
#  'safe',
#  'salutary',
#  'secure',
#  'serious',
#  'skilful',
#  'skillful',
#  'sound',
#  'soundly',
#  'thoroughly',
#  'trade_good',
#  'undecomposed',
#  'unspoiled',
#  'unspoilt',
#  'upright',
#  'well'}

# %%
set(antonyms)
# Out:
# {'bad', 'badness', 'evil', 'evilness', 'ill'}

# %%
w1 = wordnet.synset("ship.n.01")
w2 = wordnet.synset("boat.n.01")

# %%
w1
# Out:
# Synset('ship.n.01')

# %%
w2
# Out:
# Synset('boat.n.01')

# %%
w1.wup_similarity(w2)
# Out:
# 0.9090909090909091

# %%
w1 = wordnet.synset("ship.n.01")
w2 = wordnet.synset("car.n.01")
w1.wup_similarity(w2)
# Out:
# 0.6956521739130435

# %%
w1 = wordnet.synset("God.n.01")
w2 = wordnet.synset("Person.n.01")

# %%
w1.wup_similarity(w2)
# Out:
# 0.16666666666666666

# %%
w1 = wordnet.synset("Elephant.n.01")
w2 = wordnet.synset("Tiger.n.01")
w1.wup_similarity(w2)
# Out:
# 0.5714285714285714
